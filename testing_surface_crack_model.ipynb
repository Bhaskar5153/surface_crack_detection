# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.image import imread

# %%
from tensorflow.keras.models import load_model

# %%
data_dir = r'C:\Users\pbhaska2\PycharmProjects\NLP\surface data'

# %%
os.listdir(data_dir)
# Out:
# ['Testing', 'Training']

# %%
os.listdir(data_dir + '/Testing/')
# Out:
# ['Negative', 'Positive']

# %%
os.listdir(data_dir + '/Testing/' + '/Positive/')
# Out:
# ['00001.jpg',
#  '00002.jpg',
#  '00003.jpg',
#  '00004.jpg',
#  '00005.jpg',
#  '00006.jpg',
#  '00007.jpg',
#  '00008.jpg',
#  '00009.jpg',
#  '00010.jpg',
#  '00011.jpg',
#  '00012.jpg',
#  '00013.jpg',
#  '00014.jpg',
#  '00015.jpg',
#  '00016.jpg',
#  '00017.jpg',
#  '00018.jpg',
#  '00019.jpg',
#  '00020.jpg',
#  '00021.jpg',
#  '00022.jpg',
#  '00023.jpg',
#  '00024.jpg',
#  '00025.jpg',
#  '00026.jpg',
#  '00027.jpg',
#  '00028.jpg',
#  '00029.jpg',
#  '00030.jpg',
#  '00031.jpg',
#  '00032.jpg',
#  '00033.jpg',
#  '00034.jpg',
#  '00035.jpg',
#  '00036.jpg',
#  '00037.jpg',
#  '00038.jpg',
#  '00039.jpg',
#  '00040.jpg',
#  '00041.jpg',
#  '00042.jpg',
#  '00043.jpg',
#  '00044.jpg',
#  '00045.jpg',
#  '00046.jpg',
#  '00047.jpg',
#  '00048.jpg',
#  '00049.jpg',
#  '00050.jpg',
#  '00051.jpg',
#  '00052.jpg',
#  '00053.jpg',
#  '00054.jpg',
#  '00055.jpg',
#  '00056.jpg',
#  '00057.jpg',
#  '00058.jpg',
#  '00059.jpg',
#  '00060.jpg',
#  '00061.jpg',
#  '00062.jpg',
# ...

# %%
# for img_name in os.listdir(data_dir + '/Testing/' + '/Positive/'):
    
#     img = imread(data_dir + '/Testing/' + '/Positive/' + img_name)
    
#     img = np.expand_dims(img, axis=0)
    
#     model = load_model('suface_crack_model.h5')
    
#     res = np.argmax(model.predict_generator(img), axis=1)
    
#     print(res)

# %%
positive_surface = imread(data_dir + '/Testing/' + '/Positive/' + '00001.jpg')

# %%
positive_surface.shape
# Out:
# (227, 227, 3)

# %%
plt.imshow(positive_surface)

# %%
positive_surface = np.expand_dims(positive_surface, axis=0)

# %%
model = load_model('suface_crack_model.h5')

# %%
pred = np.argmax(model.predict_generator(positive_surface), axis=1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py:2035: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '

# %%
pred
# Out:
# array([0], dtype=int64)
